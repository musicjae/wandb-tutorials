# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.7/dist-packages (0.11.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: configparser>=3.8.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.1)
# Requirement already satisfied: subprocess32>=3.5.3 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.5.4)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.0.1)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb) (0.1.2)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.26.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.1.18)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: sentry-sdk>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.3.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.26.0)
# Requirement already satisfied: typing-extensions>=3.7.4.0 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (3.7.4.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (4.0.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.5.30)

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: dangamsoft (use `wandb login --relogin` to force relogin)

# %%
# %load train_lib.py

def train():
    import numpy as np
    import tensorflow as tf
    import wandb
    config_defaults = {
        'layer1_size': 128,
        'layer1_activation':'relu',
        'dropout_rate':0.2,
        'optimizer':'adam',
        'learning_rate':0.01

    }

    wandb.init(project='sweep-practice',
               config=config_defaults, 
               magic=True)
    
    config = wandb.config

    fashion_mnist = tf.keras.datasets.fashion_mnist
    (train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
    class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
                   'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

    train_images.shape
    train_images = train_images / 255.0
    test_images = test_images / 255.0

    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),
        tf.keras.layers.Dense(config.layer1_size, activation=config.layer1_activation),
        tf.keras.layers.Dropout(config.dropout_rate),
        tf.keras.layers.Dense(10, activation=tf.nn.softmax)
    ])

    if config.optimizer =='rmsprop':
        opt = tf.keras.optimizers.RMSprop(learning_rate=config.learning_rate)
    else:
        opt = tf.keras.optimizers.Adam(learning_rate=config.learning_rate)

    model.compile(optimizer=config.optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    model.fit(train_images, train_labels, epochs=5,
                  validation_data=(test_images, test_labels))

# %%
sweep_config = {
    'method': 'grid',
    'parameters': {
        'layer1_size': {
            'values': [32, 64, 96, 128, 256]
        },
        'layer1_activation':{
            'values':['relu','sigmoid']
        },
        'dropoout_rate':{
            'values':[0.1,0.2,0.3]
        },
        'optimizer':{
            'values':['adam','rmsprop']
        },
        'learning_rate':{
            'values':[0.1,0.01,0.001]
        }
    }
}

# %%
import wandb
sweep_id = wandb.sweep(sweep_config,project='sweep-practice')
# Out:
# Create sweep with ID: 7xt0toz7
# Sweep URL: https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7

# %%
wandb.agent(sweep_id, function=train)
# Out:
# wandb: Agent Starting Run: wcpeihqp with config:
# wandb: 	dropoout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 32
# wandb: 	learning_rate: 0.1
# wandb: 	optimizer: adam
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">effortless-sweep-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/dangamsoft/sweep-practice" target="_blank">https://wandb.ai/dangamsoft/sweep-practice</a><br/>
#                 Sweep page: <a href="https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7</a><br/>
# Run page: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/wcpeihqp" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/wcpeihqp</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210721_040843-wcpeihqp</code><br/><br/>
# Epoch 1/5
#    3/1875 [..............................] - ETA: 1:05 - loss: 2.3861 - accuracy: 0.1667 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0022s vs `on_train_batch_end` time: 0.0115s). Check your callbacks.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6535 - accuracy: 0.7706 - val_loss: 0.4602 - val_accuracy: 0.8380
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4714 - accuracy: 0.8311 - val_loss: 0.4302 - val_accuracy: 0.8419
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4374 - accuracy: 0.8428 - val_loss: 0.4035 - val_accuracy: 0.8568
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4153 - accuracy: 0.8501 - val_loss: 0.3960 - val_accuracy: 0.8573
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4029 - accuracy: 0.8537 - val_loss: 0.3858 - val_accuracy: 0.8611
# <br/>Waiting for W&B process to finish, PID 2969<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.60MB of 0.60MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.99377078645…
# Find user logs for this run at: <code>/content/wandb/run-20210721_040843-wcpeihqp/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210721_040843-wcpeihqp/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.40292</td></tr><tr><td>accuracy</td><td>0.85367</td></tr><tr><td>val_loss</td><td>0.38583</td></tr><tr><td>val_accuracy</td><td>0.8611</td></tr><tr><td>_runtime</td><td>28</td></tr><tr><td>_timestamp</td><td>1626840551</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.38583</td></tr><tr><td>best_epoch</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▃▂▁▁</td></tr><tr><td>accuracy</td><td>▁▆▇██</td></tr><tr><td>val_loss</td><td>█▅▃▂▁</td></tr><tr><td>val_accuracy</td><td>▁▂▇▇█</td></tr><tr><td>_runtime</td><td>▁▃▄▆█</td></tr><tr><td>_timestamp</td><td>▁▃▄▆█</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr></table><br/>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 10 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">effortless-sweep-1</strong>: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/wcpeihqp" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/wcpeihqp</a><br/>
# wandb: Agent Starting Run: msnp0bes with config:
# wandb: 	dropoout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 32
# wandb: 	learning_rate: 0.1
# wandb: 	optimizer: rmsprop
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">winter-sweep-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/dangamsoft/sweep-practice" target="_blank">https://wandb.ai/dangamsoft/sweep-practice</a><br/>
#                 Sweep page: <a href="https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7</a><br/>
# Run page: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/msnp0bes" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/msnp0bes</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210721_040916-msnp0bes</code><br/><br/>
# Epoch 1/5
#    3/1875 [..............................] - ETA: 1:14 - loss: 2.2079 - accuracy: 0.1458 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0021s vs `on_train_batch_end` time: 0.0125s). Check your callbacks.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6320 - accuracy: 0.7813 - val_loss: 0.4785 - val_accuracy: 0.8319
# Epoch 2/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4721 - accuracy: 0.8347 - val_loss: 0.4364 - val_accuracy: 0.8450
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4454 - accuracy: 0.8426 - val_loss: 0.4296 - val_accuracy: 0.8470
# Epoch 4/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4292 - accuracy: 0.8500 - val_loss: 0.4283 - val_accuracy: 0.8532
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4223 - accuracy: 0.8536 - val_loss: 0.4265 - val_accuracy: 0.8564
# <br/>Waiting for W&B process to finish, PID 3245<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.55MB of 0.56MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.99140229066…
# Find user logs for this run at: <code>/content/wandb/run-20210721_040916-msnp0bes/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210721_040916-msnp0bes/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.42231</td></tr><tr><td>accuracy</td><td>0.85357</td></tr><tr><td>val_loss</td><td>0.42649</td></tr><tr><td>val_accuracy</td><td>0.8564</td></tr><tr><td>_runtime</td><td>27</td></tr><tr><td>_timestamp</td><td>1626840583</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.42649</td></tr><tr><td>best_epoch</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▃▂▁▁</td></tr><tr><td>accuracy</td><td>▁▆▇██</td></tr><tr><td>val_loss</td><td>█▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▅▇█</td></tr><tr><td>_runtime</td><td>▁▃▅▆█</td></tr><tr><td>_timestamp</td><td>▁▃▅▆█</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr></table><br/>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 10 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">winter-sweep-2</strong>: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/msnp0bes" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/msnp0bes</a><br/>
# wandb: Agent Starting Run: 5fk1ui4c with config:
# wandb: 	dropoout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 32
# wandb: 	learning_rate: 0.01
# wandb: 	optimizer: adam
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">stoic-sweep-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/dangamsoft/sweep-practice" target="_blank">https://wandb.ai/dangamsoft/sweep-practice</a><br/>
#                 Sweep page: <a href="https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7</a><br/>
# Run page: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/5fk1ui4c" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/5fk1ui4c</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210721_040948-5fk1ui4c</code><br/><br/>
# Epoch 1/5
#    3/1875 [..............................] - ETA: 1:09 - loss: 2.2936 - accuracy: 0.2083 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0024s vs `on_train_batch_end` time: 0.0119s). Check your callbacks.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6470 - accuracy: 0.7758 - val_loss: 0.5129 - val_accuracy: 0.8081
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4715 - accuracy: 0.8322 - val_loss: 0.4229 - val_accuracy: 0.8497
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4372 - accuracy: 0.8423 - val_loss: 0.4019 - val_accuracy: 0.8570
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4163 - accuracy: 0.8511 - val_loss: 0.4082 - val_accuracy: 0.8552
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4017 - accuracy: 0.8537 - val_loss: 0.3952 - val_accuracy: 0.8545
# <br/>Waiting for W&B process to finish, PID 3511<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.60MB of 0.60MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.99511793563…
# Find user logs for this run at: <code>/content/wandb/run-20210721_040948-5fk1ui4c/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210721_040948-5fk1ui4c/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.40173</td></tr><tr><td>accuracy</td><td>0.85372</td></tr><tr><td>val_loss</td><td>0.39518</td></tr><tr><td>val_accuracy</td><td>0.8545</td></tr><tr><td>_runtime</td><td>28</td></tr><tr><td>_timestamp</td><td>1626840616</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.39518</td></tr><tr><td>best_epoch</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▃▂▁▁</td></tr><tr><td>accuracy</td><td>▁▆▇██</td></tr><tr><td>val_loss</td><td>█▃▁▂▁</td></tr><tr><td>val_accuracy</td><td>▁▇███</td></tr><tr><td>_runtime</td><td>▁▃▅▆█</td></tr><tr><td>_timestamp</td><td>▁▃▅▆█</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr></table><br/>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 10 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">stoic-sweep-3</strong>: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/5fk1ui4c" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/5fk1ui4c</a><br/>
# wandb: Agent Starting Run: 0cllj0cp with config:
# wandb: 	dropoout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 32
# wandb: 	learning_rate: 0.01
# wandb: 	optimizer: rmsprop
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">fearless-sweep-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/dangamsoft/sweep-practice" target="_blank">https://wandb.ai/dangamsoft/sweep-practice</a><br/>
#                 Sweep page: <a href="https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7</a><br/>
# Run page: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/0cllj0cp" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/0cllj0cp</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210721_041022-0cllj0cp</code><br/><br/>
# Epoch 1/5
#    3/1875 [..............................] - ETA: 1:23 - loss: 2.2867 - accuracy: 0.2292 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0029s vs `on_train_batch_end` time: 0.0134s). Check your callbacks.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6571 - accuracy: 0.7689 - val_loss: 0.4800 - val_accuracy: 0.8321
# Epoch 2/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4874 - accuracy: 0.8268 - val_loss: 0.4442 - val_accuracy: 0.8408
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4584 - accuracy: 0.8383 - val_loss: 0.4267 - val_accuracy: 0.8510
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4445 - accuracy: 0.8454 - val_loss: 0.4322 - val_accuracy: 0.8525
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4361 - accuracy: 0.8475 - val_loss: 0.4230 - val_accuracy: 0.8551
# <br/>Waiting for W&B process to finish, PID 3778<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.56MB of 0.56MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210721_041022-0cllj0cp/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210721_041022-0cllj0cp/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.43615</td></tr><tr><td>accuracy</td><td>0.84745</td></tr><tr><td>val_loss</td><td>0.42296</td></tr><tr><td>val_accuracy</td><td>0.8551</td></tr><tr><td>_runtime</td><td>27</td></tr><tr><td>_timestamp</td><td>1626840649</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.42296</td></tr><tr><td>best_epoch</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▃▂▁▁</td></tr><tr><td>accuracy</td><td>▁▆▇██</td></tr><tr><td>val_loss</td><td>█▄▁▂▁</td></tr><tr><td>val_accuracy</td><td>▁▄▇▇█</td></tr><tr><td>_runtime</td><td>▁▂▄▆█</td></tr><tr><td>_timestamp</td><td>▁▂▄▆█</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr></table><br/>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 10 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">fearless-sweep-4</strong>: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/0cllj0cp" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/0cllj0cp</a><br/>
# wandb: Agent Starting Run: o7tf1rem with config:
# wandb: 	dropoout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 32
# wandb: 	learning_rate: 0.001
# wandb: 	optimizer: adam
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">generous-sweep-5</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/dangamsoft/sweep-practice" target="_blank">https://wandb.ai/dangamsoft/sweep-practice</a><br/>
#                 Sweep page: <a href="https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7</a><br/>
# Run page: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/o7tf1rem" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/o7tf1rem</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210721_041111-o7tf1rem</code><br/><br/>
# Epoch 1/5
#    3/1875 [..............................] - ETA: 1:17 - loss: 2.3788 - accuracy: 0.1250 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0026s vs `on_train_batch_end` time: 0.0130s). Check your callbacks.
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6743 - accuracy: 0.7678 - val_loss: 0.4947 - val_accuracy: 0.8196
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4934 - accuracy: 0.8261 - val_loss: 0.4337 - val_accuracy: 0.8446
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4601 - accuracy: 0.8361 - val_loss: 0.4176 - val_accuracy: 0.8482
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4413 - accuracy: 0.8414 - val_loss: 0.4071 - val_accuracy: 0.8552
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4261 - accuracy: 0.8455 - val_loss: 0.3963 - val_accuracy: 0.8574
# <br/>Waiting for W&B process to finish, PID 4050<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.60MB of 0.60MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.99475148853…
# Find user logs for this run at: <code>/content/wandb/run-20210721_041111-o7tf1rem/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210721_041111-o7tf1rem/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.42613</td></tr><tr><td>accuracy</td><td>0.84553</td></tr><tr><td>val_loss</td><td>0.39632</td></tr><tr><td>val_accuracy</td><td>0.8574</td></tr><tr><td>_runtime</td><td>29</td></tr><tr><td>_timestamp</td><td>1626840700</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.39632</td></tr><tr><td>best_epoch</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▃▂▁▁</td></tr><tr><td>accuracy</td><td>▁▆▇██</td></tr><tr><td>val_loss</td><td>█▄▃▂▁</td></tr><tr><td>val_accuracy</td><td>▁▆▆██</td></tr><tr><td>_runtime</td><td>▁▃▅▆█</td></tr><tr><td>_timestamp</td><td>▁▃▅▆█</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr></table><br/>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 10 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">generous-sweep-5</strong>: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/o7tf1rem" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/o7tf1rem</a><br/>
# wandb: Agent Starting Run: enfax4at with config:
# wandb: 	dropoout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 32
# wandb: 	learning_rate: 0.001
# wandb: 	optimizer: rmsprop
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">ruby-sweep-6</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/dangamsoft/sweep-practice" target="_blank">https://wandb.ai/dangamsoft/sweep-practice</a><br/>
#                 Sweep page: <a href="https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7</a><br/>
# Run page: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/enfax4at" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/enfax4at</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210721_041146-enfax4at</code><br/><br/>
# Epoch 1/5
#    3/1875 [..............................] - ETA: 1:24 - loss: 2.3741 - accuracy: 0.1562 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0048s vs `on_train_batch_end` time: 0.0136s). Check your callbacks.
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6339 - accuracy: 0.7792 - val_loss: 0.4649 - val_accuracy: 0.8399
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4780 - accuracy: 0.8311 - val_loss: 0.4462 - val_accuracy: 0.8406
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4500 - accuracy: 0.8422 - val_loss: 0.4320 - val_accuracy: 0.8508
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4351 - accuracy: 0.8470 - val_loss: 0.4229 - val_accuracy: 0.8568
# Epoch 5/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4311 - accuracy: 0.8501 - val_loss: 0.4171 - val_accuracy: 0.8595
# <br/>Waiting for W&B process to finish, PID 4320<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.56MB of 0.56MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210721_041146-enfax4at/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210721_041146-enfax4at/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.43106</td></tr><tr><td>accuracy</td><td>0.8501</td></tr><tr><td>val_loss</td><td>0.41713</td></tr><tr><td>val_accuracy</td><td>0.8595</td></tr><tr><td>_runtime</td><td>28</td></tr><tr><td>_timestamp</td><td>1626840734</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.41713</td></tr><tr><td>best_epoch</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▃▂▁▁</td></tr><tr><td>accuracy</td><td>▁▆▇██</td></tr><tr><td>val_loss</td><td>█▅▃▂▁</td></tr><tr><td>val_accuracy</td><td>▁▁▅▇█</td></tr><tr><td>_runtime</td><td>▁▃▅▆█</td></tr><tr><td>_timestamp</td><td>▁▃▅▆█</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr></table><br/>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 10 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ruby-sweep-6</strong>: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/enfax4at" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/enfax4at</a><br/>
# wandb: Agent Starting Run: hsl33azs with config:
# wandb: 	dropoout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 64
# wandb: 	learning_rate: 0.1
# wandb: 	optimizer: adam
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">royal-sweep-7</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/dangamsoft/sweep-practice" target="_blank">https://wandb.ai/dangamsoft/sweep-practice</a><br/>
#                 Sweep page: <a href="https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7</a><br/>
# Run page: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/hsl33azs" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/hsl33azs</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210721_041235-hsl33azs</code><br/><br/>
# Epoch 1/5
#    3/1875 [..............................] - ETA: 1:12 - loss: 2.4369 - accuracy: 0.1458 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0031s vs `on_train_batch_end` time: 0.0118s). Check your callbacks.
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5793 - accuracy: 0.7972 - val_loss: 0.4735 - val_accuracy: 0.8311
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4300 - accuracy: 0.8464 - val_loss: 0.4041 - val_accuracy: 0.8570
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3958 - accuracy: 0.8555 - val_loss: 0.3951 - val_accuracy: 0.8566
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3736 - accuracy: 0.8644 - val_loss: 0.3766 - val_accuracy: 0.8605
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3561 - accuracy: 0.8697 - val_loss: 0.3648 - val_accuracy: 0.8704
# <br/>Waiting for W&B process to finish, PID 4586<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.89MB of 0.89MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210721_041235-hsl33azs/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210721_041235-hsl33azs/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.35614</td></tr><tr><td>accuracy</td><td>0.86968</td></tr><tr><td>val_loss</td><td>0.36484</td></tr><tr><td>val_accuracy</td><td>0.8704</td></tr><tr><td>_runtime</td><td>32</td></tr><tr><td>_timestamp</td><td>1626840787</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.36484</td></tr><tr><td>best_epoch</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▃▂▂▁</td></tr><tr><td>accuracy</td><td>▁▆▇▇█</td></tr><tr><td>val_loss</td><td>█▄▃▂▁</td></tr><tr><td>val_accuracy</td><td>▁▆▆▆█</td></tr><tr><td>_runtime</td><td>▁▃▄▆█</td></tr><tr><td>_timestamp</td><td>▁▃▄▆█</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr></table><br/>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 10 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">royal-sweep-7</strong>: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/hsl33azs" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/hsl33azs</a><br/>
# wandb: Agent Starting Run: 75kerbs0 with config:
# wandb: 	dropoout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 64
# wandb: 	learning_rate: 0.1
# wandb: 	optimizer: rmsprop
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">sunny-sweep-8</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/dangamsoft/sweep-practice" target="_blank">https://wandb.ai/dangamsoft/sweep-practice</a><br/>
#                 Sweep page: <a href="https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7</a><br/>
# Run page: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/75kerbs0" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/75kerbs0</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210721_041325-75kerbs0</code><br/><br/>
# Epoch 1/5
#    3/1875 [..............................] - ETA: 1:42 - loss: 2.2788 - accuracy: 0.2188 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0038s vs `on_train_batch_end` time: 0.0172s). Check your callbacks.
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5772 - accuracy: 0.7978 - val_loss: 0.4727 - val_accuracy: 0.8341
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4355 - accuracy: 0.8473 - val_loss: 0.4140 - val_accuracy: 0.8574
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4094 - accuracy: 0.8555 - val_loss: 0.4093 - val_accuracy: 0.8576
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3961 - accuracy: 0.8606 - val_loss: 0.4016 - val_accuracy: 0.8635
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3884 - accuracy: 0.8660 - val_loss: 0.4078 - val_accuracy: 0.8661
# <br/>Waiting for W&B process to finish, PID 4857<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.75MB of 0.75MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210721_041325-75kerbs0/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210721_041325-75kerbs0/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.38838</td></tr><tr><td>accuracy</td><td>0.86598</td></tr><tr><td>val_loss</td><td>0.40775</td></tr><tr><td>val_accuracy</td><td>0.8661</td></tr><tr><td>_runtime</td><td>32</td></tr><tr><td>_timestamp</td><td>1626840837</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.40161</td></tr><tr><td>best_epoch</td><td>3</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▃▂▁▁</td></tr><tr><td>accuracy</td><td>▁▆▇▇█</td></tr><tr><td>val_loss</td><td>█▂▂▁▂</td></tr><tr><td>val_accuracy</td><td>▁▆▆▇█</td></tr><tr><td>_runtime</td><td>▁▃▅▆█</td></tr><tr><td>_timestamp</td><td>▁▃▅▆█</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr></table><br/>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 10 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">sunny-sweep-8</strong>: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/75kerbs0" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/75kerbs0</a><br/>
# wandb: Agent Starting Run: sigxbs4b with config:
# wandb: 	dropoout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 64
# wandb: 	learning_rate: 0.01
# wandb: 	optimizer: adam
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">amber-sweep-9</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/dangamsoft/sweep-practice" target="_blank">https://wandb.ai/dangamsoft/sweep-practice</a><br/>
#                 Sweep page: <a href="https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7</a><br/>
# Run page: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/sigxbs4b" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/sigxbs4b</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210721_041416-sigxbs4b</code><br/><br/>
# Epoch 1/5
#    3/1875 [..............................] - ETA: 1:26 - loss: 2.3980 - accuracy: 0.1667 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0034s vs `on_train_batch_end` time: 0.0143s). Check your callbacks.
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5688 - accuracy: 0.8018 - val_loss: 0.4397 - val_accuracy: 0.8411
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4201 - accuracy: 0.8487 - val_loss: 0.3976 - val_accuracy: 0.8546
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3872 - accuracy: 0.8624 - val_loss: 0.3831 - val_accuracy: 0.8667
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3637 - accuracy: 0.8683 - val_loss: 0.3713 - val_accuracy: 0.8675
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3515 - accuracy: 0.8712 - val_loss: 0.3689 - val_accuracy: 0.8646
# <br/>Waiting for W&B process to finish, PID 5123<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.89MB of 0.89MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210721_041416-sigxbs4b/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210721_041416-sigxbs4b/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.35153</td></tr><tr><td>accuracy</td><td>0.87122</td></tr><tr><td>val_loss</td><td>0.36889</td></tr><tr><td>val_accuracy</td><td>0.8646</td></tr><tr><td>_runtime</td><td>33</td></tr><tr><td>_timestamp</td><td>1626840889</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.36889</td></tr><tr><td>best_epoch</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▃▂▁▁</td></tr><tr><td>accuracy</td><td>▁▆▇██</td></tr><tr><td>val_loss</td><td>█▄▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅██▇</td></tr><tr><td>_runtime</td><td>▁▃▅▆█</td></tr><tr><td>_timestamp</td><td>▁▃▅▆█</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr></table><br/>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 10 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">amber-sweep-9</strong>: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/sigxbs4b" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/sigxbs4b</a><br/>
# wandb: Agent Starting Run: 8yhw9cys with config:
# wandb: 	dropoout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 64
# wandb: 	learning_rate: 0.01
# wandb: 	optimizer: rmsprop
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">dainty-sweep-10</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/dangamsoft/sweep-practice" target="_blank">https://wandb.ai/dangamsoft/sweep-practice</a><br/>
#                 Sweep page: <a href="https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7</a><br/>
# Run page: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/8yhw9cys" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/8yhw9cys</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210721_041507-8yhw9cys</code><br/><br/>
# Epoch 1/5
#    3/1875 [..............................] - ETA: 1:36 - loss: 2.1318 - accuracy: 0.2292 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0067s vs `on_train_batch_end` time: 0.0149s). Check your callbacks.
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5676 - accuracy: 0.8021 - val_loss: 0.4509 - val_accuracy: 0.8392
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4305 - accuracy: 0.8490 - val_loss: 0.4479 - val_accuracy: 0.8423
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4082 - accuracy: 0.8568 - val_loss: 0.4147 - val_accuracy: 0.8582
# Epoch 4/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3958 - accuracy: 0.8647 - val_loss: 0.4275 - val_accuracy: 0.8581
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3850 - accuracy: 0.8673 - val_loss: 0.4096 - val_accuracy: 0.8697
# <br/>Waiting for W&B process to finish, PID 5394<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.75MB of 0.75MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210721_041507-8yhw9cys/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210721_041507-8yhw9cys/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.38495</td></tr><tr><td>accuracy</td><td>0.86733</td></tr><tr><td>val_loss</td><td>0.40962</td></tr><tr><td>val_accuracy</td><td>0.8697</td></tr><tr><td>_runtime</td><td>32</td></tr><tr><td>_timestamp</td><td>1626840939</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.40962</td></tr><tr><td>best_epoch</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▃▂▁▁</td></tr><tr><td>accuracy</td><td>▁▆▇██</td></tr><tr><td>val_loss</td><td>█▇▂▄▁</td></tr><tr><td>val_accuracy</td><td>▁▂▅▅█</td></tr><tr><td>_runtime</td><td>▁▃▅▆█</td></tr><tr><td>_timestamp</td><td>▁▃▅▆█</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr></table><br/>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 10 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">dainty-sweep-10</strong>: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/8yhw9cys" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/8yhw9cys</a><br/>
# wandb: Agent Starting Run: lup8ab9x with config:
# wandb: 	dropoout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	optimizer: adam
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">wild-sweep-11</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/dangamsoft/sweep-practice" target="_blank">https://wandb.ai/dangamsoft/sweep-practice</a><br/>
#                 Sweep page: <a href="https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/sweeps/7xt0toz7</a><br/>
# Run page: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/lup8ab9x" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/lup8ab9x</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210721_041558-lup8ab9x</code><br/><br/>
# Epoch 1/5
#    3/1875 [..............................] - ETA: 1:25 - loss: 2.3175 - accuracy: 0.2188 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0034s vs `on_train_batch_end` time: 0.0154s). Check your callbacks.
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5693 - accuracy: 0.7987 - val_loss: 0.4548 - val_accuracy: 0.8345
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4235 - accuracy: 0.8468 - val_loss: 0.4094 - val_accuracy: 0.8522
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3893 - accuracy: 0.8589 - val_loss: 0.3827 - val_accuracy: 0.8641
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3699 - accuracy: 0.8671 - val_loss: 0.3838 - val_accuracy: 0.8607
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3539 - accuracy: 0.8687 - val_loss: 0.3682 - val_accuracy: 0.8658
# <br/>Waiting for W&B process to finish, PID 5662<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.89MB of 0.89MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210721_041558-lup8ab9x/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210721_041558-lup8ab9x/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.35389</td></tr><tr><td>accuracy</td><td>0.86873</td></tr><tr><td>val_loss</td><td>0.36824</td></tr><tr><td>val_accuracy</td><td>0.8658</td></tr><tr><td>_runtime</td><td>34</td></tr><tr><td>_timestamp</td><td>1626840992</td></tr><tr><td>_step</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.36824</td></tr><tr><td>best_epoch</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▃▂▂▁</td></tr><tr><td>accuracy</td><td>▁▆▇██</td></tr><tr><td>val_loss</td><td>█▄▂▂▁</td></tr><tr><td>val_accuracy</td><td>▁▅█▇█</td></tr><tr><td>_runtime</td><td>▁▃▄▆█</td></tr><tr><td>_timestamp</td><td>▁▃▄▆█</td></tr><tr><td>_step</td><td>▁▃▅▆█</td></tr></table><br/>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 10 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">wild-sweep-11</strong>: <a href="https://wandb.ai/dangamsoft/sweep-practice/runs/lup8ab9x" target="_blank">https://wandb.ai/dangamsoft/sweep-practice/runs/lup8ab9x</a><br/>
# wandb: Agent Starting Run: dkrmla6o with config:
# wandb: 	dropoout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 64
# wandb: 	learning_rate: 0.001
# wandb: 	optimizer: rmsprop
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: Ctrl + C detected. Stopping sweep.

# %%
with open("train.py","w") as f:
    f.write("""
def train():
    import numpy as np
    import tensorflow as tf
    import wandb
    config_defaults = {
        'layer1_size': 128,
        'layer1_activation':'relu',
        'dropout_rate':0.2,
        'optimizer':'adam',
        'learning_rate':0.01

    }

    wandb.init(project='sweep-practice',
            config=config_defaults, 
            magic=True)
    
    config = wandb.config

    fashion_mnist = tf.keras.datasets.fashion_mnist
    (train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
    class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
                'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

    train_images.shape
    train_images = train_images / 255.0
    test_images = test_images / 255.0

    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),
        tf.keras.layers.Dense(config.layer1_size, activation=config.layer1_activation),
        tf.keras.layers.Dropout(config.dropout_rate),
        tf.keras.layers.Dense(10, activation=tf.nn.softmax)
    ])

    if config.optimizer =='rmsprop':
        opt = tf.keras.optimizers.RMSprop(learning_rate=config.learning_rate)
    else:
        opt = tf.keras.optimizers.Adam(learning_rate=config.learning_rate)

    model.compile(optimizer=config.optimizer,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
    
    model.fit(train_images, train_labels, epochs=5,
                validation_data=(test_images, test_labels))
    
    """)

# %%
# !head train.py
# Out:
#     def train():
#         import numpy as np
#         import tensorflow as tf
#         import wandb
#         config_defaults = {
#             'layer1_size': 128,
#             'layer1_activation':'relu',
#             'dropout_rate':0.2,
#             'optimizer':'adam',

# %%
# !wandb agent dangamsoft/sweep-practice/hecs1nne
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 	dropout_rate: 0.24888920263272651
# 	layer1_activation: relu
# 	layer1_size: 25
# 	layer_activation: relu
# 	layer_size: 55
# 	learning_rate: 0.16631879444203013
# 	optimizer: rmsprop
# 2021-07-21 04:26:28,357 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.10872443334436839 --dropout_rate=0.24888920263272651 --layer1_activation=relu --layer1_size=25 --layer_activation=relu --layer_size=55 --learning_rate=0.16631879444203013 --optimizer=rmsprop
# 2021-07-21 04:26:33,368 - wandb.wandb_agent - INFO - Running runs: ['drsf7hf5']
# 2021-07-21 04:26:33,369 - wandb.wandb_agent - INFO - Cleaning up finished run: drsf7hf5
# 2021-07-21 04:26:33,628 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:26:33,628 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.07468507527870745
# 	dropout_rate: 0.3287281453132421
# 	layer1_activation: relu
# 	layer1_size: 214
# 	layer_activation: relu
# 	layer_size: 42
# 	learning_rate: 0.12409452069864413
# 	optimizer: adam
# 2021-07-21 04:26:33,630 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.07468507527870745 --dropout_rate=0.3287281453132421 --layer1_activation=relu --layer1_size=214 --layer_activation=relu --layer_size=42 --learning_rate=0.12409452069864413 --optimizer=adam
# 2021-07-21 04:26:38,641 - wandb.wandb_agent - INFO - Running runs: ['bkboe6k0']
# 2021-07-21 04:26:38,642 - wandb.wandb_agent - INFO - Cleaning up finished run: bkboe6k0
# 2021-07-21 04:26:38,891 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:26:38,891 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.10984955880817635
# 	dropout_rate: 0.14596355158250018
# 	layer1_activation: relu
# 	layer1_size: 246
# 	layer_activation: relu
# 	layer_size: 53
# 	learning_rate: 0.07675267921636346
# 	optimizer: adam
# 2021-07-21 04:26:38,894 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.10984955880817635 --dropout_rate=0.14596355158250018 --layer1_activation=relu --layer1_size=246 --layer_activation=relu --layer_size=53 --learning_rate=0.07675267921636346 --optimizer=adam
# 2021-07-21 04:26:43,908 - wandb.wandb_agent - INFO - Running runs: ['oysfe7cz']
# 2021-07-21 04:26:43,908 - wandb.wandb_agent - INFO - Cleaning up finished run: oysfe7cz
# 2021-07-21 04:26:44,657 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:26:44,658 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.1012068292281634
# 	dropout_rate: 0.2705132466577532
# 	layer1_activation: relu
# 	layer1_size: 134
# 	layer_activation: relu
# 	layer_size: 48
# 	learning_rate: 0.19323149675410312
# 	optimizer: rmsprop
# 2021-07-21 04:26:44,660 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.1012068292281634 --dropout_rate=0.2705132466577532 --layer1_activation=relu --layer1_size=134 --layer_activation=relu --layer_size=48 --learning_rate=0.19323149675410312 --optimizer=rmsprop
# 2021-07-21 04:26:49,672 - wandb.wandb_agent - INFO - Running runs: ['ciuahasx']
# 2021-07-21 04:26:49,673 - wandb.wandb_agent - INFO - Cleaning up finished run: ciuahasx
# 2021-07-21 04:26:49,956 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:26:49,956 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.09090974452902925
# 	dropout_rate: 0.35746439774757033
# 	layer1_activation: relu
# 	layer1_size: 174
# 	layer_activation: relu
# 	layer_size: 46
# 	learning_rate: 0.08767179392863092
# 	optimizer: adam
# 2021-07-21 04:26:49,958 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.09090974452902925 --dropout_rate=0.35746439774757033 --layer1_activation=relu --layer1_size=174 --layer_activation=relu --layer_size=46 --learning_rate=0.08767179392863092 --optimizer=adam
# 2021-07-21 04:26:54,971 - wandb.wandb_agent - INFO - Running runs: ['thkxf3vt']
# 2021-07-21 04:26:54,972 - wandb.wandb_agent - INFO - Cleaning up finished run: thkxf3vt
# 2021-07-21 04:26:55,287 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:26:55,287 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.16124783250753555
# 	dropout_rate: 0.20994566594659758
# 	layer1_activation: relu
# 	layer1_size: 215
# 	layer_activation: relu
# 	layer_size: 58
# 	learning_rate: 0.10693654075018552
# 	optimizer: rmsprop
# 2021-07-21 04:26:55,290 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.16124783250753555 --dropout_rate=0.20994566594659758 --layer1_activation=relu --layer1_size=215 --layer_activation=relu --layer_size=58 --learning_rate=0.10693654075018552 --optimizer=rmsprop
# 2021-07-21 04:27:00,301 - wandb.wandb_agent - INFO - Running runs: ['sfz47n42']
# 2021-07-21 04:27:00,301 - wandb.wandb_agent - INFO - Cleaning up finished run: sfz47n42
# 2021-07-21 04:27:00,565 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:27:00,565 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.17978096638436458
# 	dropout_rate: 0.1772541513028753
# 	layer1_activation: relu
# 	layer1_size: 255
# 	layer_activation: relu
# 	layer_size: 33
# 	learning_rate: 0.16884914379004487
# 	optimizer: adam
# 2021-07-21 04:27:00,567 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.17978096638436458 --dropout_rate=0.1772541513028753 --layer1_activation=relu --layer1_size=255 --layer_activation=relu --layer_size=33 --learning_rate=0.16884914379004487 --optimizer=adam
# 2021-07-21 04:27:05,582 - wandb.wandb_agent - INFO - Running runs: ['sxzgo9nw']
# 2021-07-21 04:27:05,582 - wandb.wandb_agent - INFO - Cleaning up finished run: sxzgo9nw
# 2021-07-21 04:27:05,860 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:27:05,860 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.17889507400838206
# 	dropout_rate: 0.232803370230208
# 	layer1_activation: relu
# 	layer1_size: 173
# 	layer_activation: relu
# 	layer_size: 47
# 	learning_rate: 0.13854124212459826
# 	optimizer: adam
# 2021-07-21 04:27:05,862 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.17889507400838206 --dropout_rate=0.232803370230208 --layer1_activation=relu --layer1_size=173 --layer_activation=relu --layer_size=47 --learning_rate=0.13854124212459826 --optimizer=adam
# 2021-07-21 04:27:10,875 - wandb.wandb_agent - INFO - Running runs: ['xulnc7lp']
# 2021-07-21 04:27:10,876 - wandb.wandb_agent - INFO - Cleaning up finished run: xulnc7lp
# 2021-07-21 04:27:11,159 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:27:11,160 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.10356061807154834
# 	dropout_rate: 0.19047349886214482
# 	layer1_activation: relu
# 	layer1_size: 250
# 	layer_activation: relu
# 	layer_size: 30
# 	learning_rate: 0.05253056804164233
# 	optimizer: rmsprop
# 2021-07-21 04:27:11,162 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.10356061807154834 --dropout_rate=0.19047349886214482 --layer1_activation=relu --layer1_size=250 --layer_activation=relu --layer_size=30 --learning_rate=0.05253056804164233 --optimizer=rmsprop
# 2021-07-21 04:27:16,175 - wandb.wandb_agent - INFO - Running runs: ['x26kldb3']
# 2021-07-21 04:27:16,176 - wandb.wandb_agent - INFO - Cleaning up finished run: x26kldb3
# 2021-07-21 04:27:16,427 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:27:16,427 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.1987661182693447
# 	dropout_rate: 0.3953685861806816
# 	layer1_activation: relu
# 	layer1_size: 175
# 	layer_activation: relu
# 	layer_size: 63
# 	learning_rate: 0.17697836199976216
# 	optimizer: adam
# 2021-07-21 04:27:16,430 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.1987661182693447 --dropout_rate=0.3953685861806816 --layer1_activation=relu --layer1_size=175 --layer_activation=relu --layer_size=63 --learning_rate=0.17697836199976216 --optimizer=adam
# 2021-07-21 04:27:21,442 - wandb.wandb_agent - INFO - Running runs: ['15fboamm']
# 2021-07-21 04:27:21,443 - wandb.wandb_agent - INFO - Cleaning up finished run: 15fboamm
# 2021-07-21 04:27:21,892 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:27:21,892 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.07364728726379123
# 	dropout_rate: 0.37179731273352123
# 	layer1_activation: relu
# 	layer1_size: 149
# 	layer_activation: relu
# 	layer_size: 48
# 	learning_rate: 0.054868354172545
# 	optimizer: rmsprop
# 2021-07-21 04:27:21,894 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.07364728726379123 --dropout_rate=0.37179731273352123 --layer1_activation=relu --layer1_size=149 --layer_activation=relu --layer_size=48 --learning_rate=0.054868354172545 --optimizer=rmsprop
# 2021-07-21 04:27:26,903 - wandb.wandb_agent - INFO - Running runs: ['syz55k7z']
# 2021-07-21 04:27:26,904 - wandb.wandb_agent - INFO - Cleaning up finished run: syz55k7z
# 2021-07-21 04:27:27,209 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:27:27,209 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.08950361925756209
# 	dropout_rate: 0.17194509112585984
# 	layer1_activation: relu
# 	layer1_size: 173
# 	layer_activation: relu
# 	layer_size: 37
# 	learning_rate: 0.07741726085231801
# 	optimizer: rmsprop
# 2021-07-21 04:27:27,211 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.08950361925756209 --dropout_rate=0.17194509112585984 --layer1_activation=relu --layer1_size=173 --layer_activation=relu --layer_size=37 --learning_rate=0.07741726085231801 --optimizer=rmsprop
# 2021-07-21 04:27:32,223 - wandb.wandb_agent - INFO - Running runs: ['wvhdmeey']
# 2021-07-21 04:27:32,224 - wandb.wandb_agent - INFO - Cleaning up finished run: wvhdmeey
# 2021-07-21 04:27:32,493 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:27:32,493 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.17385578281769032
# 	dropout_rate: 0.1365733008212836
# 	layer1_activation: relu
# 	layer1_size: 251
# 	layer_activation: relu
# 	layer_size: 50
# 	learning_rate: 0.10687103356960519
# 	optimizer: adam
# 2021-07-21 04:27:32,495 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.17385578281769032 --dropout_rate=0.1365733008212836 --layer1_activation=relu --layer1_size=251 --layer_activation=relu --layer_size=50 --learning_rate=0.10687103356960519 --optimizer=adam
# 2021-07-21 04:27:37,507 - wandb.wandb_agent - INFO - Running runs: ['20x1q40o']
# 2021-07-21 04:27:37,508 - wandb.wandb_agent - INFO - Cleaning up finished run: 20x1q40o
# 2021-07-21 04:27:37,791 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:27:37,791 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.17613741101255215
# 	dropout_rate: 0.24875920823532952
# 	layer1_activation: relu
# 	layer1_size: 140
# 	layer_activation: relu
# 	layer_size: 57
# 	learning_rate: 0.15489241807472215
# 	optimizer: rmsprop
# 2021-07-21 04:27:37,794 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.17613741101255215 --dropout_rate=0.24875920823532952 --layer1_activation=relu --layer1_size=140 --layer_activation=relu --layer_size=57 --learning_rate=0.15489241807472215 --optimizer=rmsprop
# 2021-07-21 04:27:42,806 - wandb.wandb_agent - INFO - Running runs: ['k863rikh']
# 2021-07-21 04:27:42,807 - wandb.wandb_agent - INFO - Cleaning up finished run: k863rikh
# 2021-07-21 04:27:43,074 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:27:43,075 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.17141855202121742
# 	dropout_rate: 0.10166882473001645
# 	layer1_activation: relu
# 	layer1_size: 185
# 	layer_activation: relu
# 	layer_size: 32
# 	learning_rate: 0.16045478691056403
# 	optimizer: adam
# 2021-07-21 04:27:43,078 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.17141855202121742 --dropout_rate=0.10166882473001645 --layer1_activation=relu --layer1_size=185 --layer_activation=relu --layer_size=32 --learning_rate=0.16045478691056403 --optimizer=adam
# 2021-07-21 04:27:48,090 - wandb.wandb_agent - INFO - Running runs: ['5d4gdp2a']
# 2021-07-21 04:27:48,091 - wandb.wandb_agent - INFO - Cleaning up finished run: 5d4gdp2a
# 2021-07-21 04:27:48,346 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:27:48,347 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.05134034867270728
# 	dropout_rate: 0.20948609119501105
# 	layer1_activation: relu
# 	layer1_size: 180
# 	layer_activation: relu
# 	layer_size: 62
# 	learning_rate: 0.15572897262000895
# 	optimizer: adam
# 2021-07-21 04:27:48,349 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.05134034867270728 --dropout_rate=0.20948609119501105 --layer1_activation=relu --layer1_size=180 --layer_activation=relu --layer_size=62 --learning_rate=0.15572897262000895 --optimizer=adam
# 2021-07-21 04:27:53,360 - wandb.wandb_agent - INFO - Running runs: ['jecuqaa6']
# 2021-07-21 04:27:53,361 - wandb.wandb_agent - INFO - Cleaning up finished run: jecuqaa6
# 2021-07-21 04:27:54,057 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:27:54,057 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.14610393728348328
# 	dropout_rate: 0.1907297170928352
# 	layer1_activation: relu
# 	layer1_size: 16
# 	layer_activation: relu
# 	layer_size: 64
# 	learning_rate: 0.031005852542817347
# 	optimizer: rmsprop
# 2021-07-21 04:27:54,060 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.14610393728348328 --dropout_rate=0.1907297170928352 --layer1_activation=relu --layer1_size=16 --layer_activation=relu --layer_size=64 --learning_rate=0.031005852542817347 --optimizer=rmsprop
# 2021-07-21 04:27:59,071 - wandb.wandb_agent - INFO - Running runs: ['i8zkyr9n']
# 2021-07-21 04:27:59,071 - wandb.wandb_agent - INFO - Cleaning up finished run: i8zkyr9n
# 2021-07-21 04:27:59,324 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:27:59,324 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.0772322249600793
# 	dropout_rate: 0.104098466858462
# 	layer1_activation: relu
# 	layer1_size: 24
# 	layer_activation: relu
# 	layer_size: 40
# 	learning_rate: 0.1741387727241385
# 	optimizer: rmsprop
# 2021-07-21 04:27:59,326 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.0772322249600793 --dropout_rate=0.104098466858462 --layer1_activation=relu --layer1_size=24 --layer_activation=relu --layer_size=40 --learning_rate=0.1741387727241385 --optimizer=rmsprop
# 2021-07-21 04:28:04,338 - wandb.wandb_agent - INFO - Running runs: ['0y3jqhxh']
# 2021-07-21 04:28:04,339 - wandb.wandb_agent - INFO - Cleaning up finished run: 0y3jqhxh
# 2021-07-21 04:28:04,640 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:28:04,640 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.05328975958100135
# 	dropout_rate: 0.18608882066959026
# 	layer1_activation: relu
# 	layer1_size: 58
# 	layer_activation: relu
# 	layer_size: 25
# 	learning_rate: 0.0611760545875426
# 	optimizer: rmsprop
# 2021-07-21 04:28:04,642 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.05328975958100135 --dropout_rate=0.18608882066959026 --layer1_activation=relu --layer1_size=58 --layer_activation=relu --layer_size=25 --learning_rate=0.0611760545875426 --optimizer=rmsprop
# 2021-07-21 04:28:09,654 - wandb.wandb_agent - INFO - Running runs: ['g151tb4x']
# 2021-07-21 04:28:09,655 - wandb.wandb_agent - INFO - Cleaning up finished run: g151tb4x
# 2021-07-21 04:28:09,905 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:28:09,905 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.06893129937852358
# 	dropout_rate: 0.26935565474531914
# 	layer1_activation: relu
# 	layer1_size: 92
# 	layer_activation: relu
# 	layer_size: 45
# 	learning_rate: 0.03768945599259178
# 	optimizer: rmsprop
# 2021-07-21 04:28:09,907 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.06893129937852358 --dropout_rate=0.26935565474531914 --layer1_activation=relu --layer1_size=92 --layer_activation=relu --layer_size=45 --learning_rate=0.03768945599259178 --optimizer=rmsprop
# 2021-07-21 04:28:14,920 - wandb.wandb_agent - INFO - Running runs: ['0zhwtowt']
# 2021-07-21 04:28:14,921 - wandb.wandb_agent - INFO - Cleaning up finished run: 0zhwtowt
# 2021-07-21 04:28:15,353 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:28:15,353 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.11454234454068238
# 	dropout_rate: 0.3264952471706092
# 	layer1_activation: relu
# 	layer1_size: 104
# 	layer_activation: relu
# 	layer_size: 61
# 	learning_rate: 0.18557397262404454
# 	optimizer: adam
# 2021-07-21 04:28:15,355 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.11454234454068238 --dropout_rate=0.3264952471706092 --layer1_activation=relu --layer1_size=104 --layer_activation=relu --layer_size=61 --learning_rate=0.18557397262404454 --optimizer=adam
# 2021-07-21 04:28:20,369 - wandb.wandb_agent - INFO - Running runs: ['j4ddts1v']
# 2021-07-21 04:28:20,370 - wandb.wandb_agent - INFO - Cleaning up finished run: j4ddts1v
# 2021-07-21 04:28:20,657 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:28:20,657 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.16611141893220244
# 	dropout_rate: 0.37982527771927543
# 	layer1_activation: relu
# 	layer1_size: 188
# 	layer_activation: relu
# 	layer_size: 38
# 	learning_rate: 0.11190941174798953
# 	optimizer: rmsprop
# 2021-07-21 04:28:20,660 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.16611141893220244 --dropout_rate=0.37982527771927543 --layer1_activation=relu --layer1_size=188 --layer_activation=relu --layer_size=38 --learning_rate=0.11190941174798953 --optimizer=rmsprop
# 2021-07-21 04:28:25,674 - wandb.wandb_agent - INFO - Running runs: ['fxxssof3']
# 2021-07-21 04:28:25,675 - wandb.wandb_agent - INFO - Cleaning up finished run: fxxssof3
# 2021-07-21 04:28:26,047 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:28:26,048 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.07799745125586614
# 	dropout_rate: 0.3584712602921508
# 	layer1_activation: relu
# 	layer1_size: 61
# 	layer_activation: relu
# 	layer_size: 62
# 	learning_rate: 0.05034994156022159
# 	optimizer: adam
# 2021-07-21 04:28:26,050 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.07799745125586614 --dropout_rate=0.3584712602921508 --layer1_activation=relu --layer1_size=61 --layer_activation=relu --layer_size=62 --learning_rate=0.05034994156022159 --optimizer=adam
# 2021-07-21 04:28:31,061 - wandb.wandb_agent - INFO - Running runs: ['yrt43irj']
# 2021-07-21 04:28:31,062 - wandb.wandb_agent - INFO - Cleaning up finished run: yrt43irj
# 2021-07-21 04:28:31,378 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:28:31,378 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.19822172834348134
# 	dropout_rate: 0.3173280462737879
# 	layer1_activation: relu
# 	layer1_size: 245
# 	layer_activation: relu
# 	layer_size: 53
# 	learning_rate: 0.014747739285469443
# 	optimizer: rmsprop
# 2021-07-21 04:28:31,380 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.19822172834348134 --dropout_rate=0.3173280462737879 --layer1_activation=relu --layer1_size=245 --layer_activation=relu --layer_size=53 --learning_rate=0.014747739285469443 --optimizer=rmsprop
# 2021-07-21 04:28:36,391 - wandb.wandb_agent - INFO - Running runs: ['2cvvbr2o']
# 2021-07-21 04:28:36,392 - wandb.wandb_agent - INFO - Cleaning up finished run: 2cvvbr2o
# 2021-07-21 04:28:36,676 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:28:36,677 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.18605751117136565
# 	dropout_rate: 0.2755624941552086
# 	layer1_activation: relu
# 	layer1_size: 169
# 	layer_activation: relu
# 	layer_size: 27
# 	learning_rate: 0.19211162139679733
# 	optimizer: adam
# 2021-07-21 04:28:36,679 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.18605751117136565 --dropout_rate=0.2755624941552086 --layer1_activation=relu --layer1_size=169 --layer_activation=relu --layer_size=27 --learning_rate=0.19211162139679733 --optimizer=adam
# 2021-07-21 04:28:41,691 - wandb.wandb_agent - INFO - Running runs: ['brzjzg2d']
# 2021-07-21 04:28:41,692 - wandb.wandb_agent - INFO - Cleaning up finished run: brzjzg2d
# 2021-07-21 04:28:41,949 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:28:41,949 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.19285733540265726
# 	dropout_rate: 0.20652426487819556
# 	layer1_activation: relu
# 	layer1_size: 72
# 	layer_activation: relu
# 	layer_size: 53
# 	learning_rate: 0.12986563773029464
# 	optimizer: rmsprop
# 2021-07-21 04:28:41,951 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.19285733540265726 --dropout_rate=0.20652426487819556 --layer1_activation=relu --layer1_size=72 --layer_activation=relu --layer_size=53 --learning_rate=0.12986563773029464 --optimizer=rmsprop
# 2021-07-21 04:28:46,963 - wandb.wandb_agent - INFO - Running runs: ['4yrg3910']
# 2021-07-21 04:28:46,963 - wandb.wandb_agent - INFO - Cleaning up finished run: 4yrg3910
# 2021-07-21 04:28:47,242 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:28:47,242 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.08833340269145501
# 	dropout_rate: 0.25790305503555155
# 	layer1_activation: relu
# 	layer1_size: 147
# 	layer_activation: relu
# 	layer_size: 34
# 	learning_rate: 0.1769894806812423
# 	optimizer: adam
# 2021-07-21 04:28:47,245 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.08833340269145501 --dropout_rate=0.25790305503555155 --layer1_activation=relu --layer1_size=147 --layer_activation=relu --layer_size=34 --learning_rate=0.1769894806812423 --optimizer=adam
# 2021-07-21 04:28:52,256 - wandb.wandb_agent - INFO - Running runs: ['bqmd1ghn']
# 2021-07-21 04:28:52,257 - wandb.wandb_agent - INFO - Cleaning up finished run: bqmd1ghn
# 2021-07-21 04:28:52,567 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:28:52,567 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.08643882633960953
# 	dropout_rate: 0.14538447642277494
# 	layer1_activation: relu
# 	layer1_size: 34
# 	layer_activation: relu
# 	layer_size: 31
# 	learning_rate: 0.18331701370251974
# 	optimizer: rmsprop
# 2021-07-21 04:28:52,569 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.08643882633960953 --dropout_rate=0.14538447642277494 --layer1_activation=relu --layer1_size=34 --layer_activation=relu --layer_size=31 --learning_rate=0.18331701370251974 --optimizer=rmsprop
# 2021-07-21 04:28:57,585 - wandb.wandb_agent - INFO - Running runs: ['esem1j82']
# 2021-07-21 04:28:57,585 - wandb.wandb_agent - INFO - Cleaning up finished run: esem1j82
# 2021-07-21 04:28:57,821 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:28:57,821 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.10269325326407622
# 	dropout_rate: 0.3378427984461555
# 	layer1_activation: relu
# 	layer1_size: 144
# 	layer_activation: relu
# 	layer_size: 63
# 	learning_rate: 0.06573873265464247
# 	optimizer: rmsprop
# 2021-07-21 04:28:57,823 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.10269325326407622 --dropout_rate=0.3378427984461555 --layer1_activation=relu --layer1_size=144 --layer_activation=relu --layer_size=63 --learning_rate=0.06573873265464247 --optimizer=rmsprop
# 2021-07-21 04:29:02,835 - wandb.wandb_agent - INFO - Running runs: ['etie120m']
# 2021-07-21 04:29:02,835 - wandb.wandb_agent - INFO - Cleaning up finished run: etie120m
# 2021-07-21 04:29:03,091 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:29:03,091 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.10845131381694086
# 	dropout_rate: 0.15674392047264984
# 	layer1_activation: relu
# 	layer1_size: 149
# 	layer_activation: relu
# 	layer_size: 62
# 	learning_rate: 0.10179551106187092
# 	optimizer: adam
# 2021-07-21 04:29:03,093 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.10845131381694086 --dropout_rate=0.15674392047264984 --layer1_activation=relu --layer1_size=149 --layer_activation=relu --layer_size=62 --learning_rate=0.10179551106187092 --optimizer=adam
# 2021-07-21 04:29:08,107 - wandb.wandb_agent - INFO - Running runs: ['07hfxu6z']
# 2021-07-21 04:29:08,108 - wandb.wandb_agent - INFO - Cleaning up finished run: 07hfxu6z
# 2021-07-21 04:29:08,441 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:29:08,442 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.18727519776129598
# 	dropout_rate: 0.12175841863391057
# 	layer1_activation: relu
# 	layer1_size: 151
# 	layer_activation: relu
# 	layer_size: 59
# 	learning_rate: 0.18144613152998812
# 	optimizer: adam
# 2021-07-21 04:29:08,444 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.18727519776129598 --dropout_rate=0.12175841863391057 --layer1_activation=relu --layer1_size=151 --layer_activation=relu --layer_size=59 --learning_rate=0.18144613152998812 --optimizer=adam
# 2021-07-21 04:29:13,457 - wandb.wandb_agent - INFO - Running runs: ['s142olj0']
# 2021-07-21 04:29:13,458 - wandb.wandb_agent - INFO - Cleaning up finished run: s142olj0
# 2021-07-21 04:29:13,728 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:29:13,729 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.0902889212400558
# 	dropout_rate: 0.2055744572831503
# 	layer1_activation: relu
# 	layer1_size: 103
# 	layer_activation: relu
# 	layer_size: 45
# 	learning_rate: 0.12795495494630996
# 	optimizer: adam
# 2021-07-21 04:29:13,733 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.0902889212400558 --dropout_rate=0.2055744572831503 --layer1_activation=relu --layer1_size=103 --layer_activation=relu --layer_size=45 --learning_rate=0.12795495494630996 --optimizer=adam
# 2021-07-21 04:29:18,756 - wandb.wandb_agent - INFO - Running runs: ['z3f2h138']
# 2021-07-21 04:29:18,757 - wandb.wandb_agent - INFO - Cleaning up finished run: z3f2h138
# 2021-07-21 04:29:19,178 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:29:19,178 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.09228423996681141
# 	dropout_rate: 0.18328085675580863
# 	layer1_activation: relu
# 	layer1_size: 251
# 	layer_activation: relu
# 	layer_size: 56
# 	learning_rate: 0.03586132132934323
# 	optimizer: adam
# 2021-07-21 04:29:19,180 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.09228423996681141 --dropout_rate=0.18328085675580863 --layer1_activation=relu --layer1_size=251 --layer_activation=relu --layer_size=56 --learning_rate=0.03586132132934323 --optimizer=adam
# 2021-07-21 04:29:24,194 - wandb.wandb_agent - INFO - Running runs: ['tuuwqhbd']
# 2021-07-21 04:29:24,194 - wandb.wandb_agent - INFO - Cleaning up finished run: tuuwqhbd
# 2021-07-21 04:29:24,938 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:29:24,938 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.17470454065187083
# 	dropout_rate: 0.1544424843904443
# 	layer1_activation: relu
# 	layer1_size: 251
# 	layer_activation: relu
# 	layer_size: 53
# 	learning_rate: 0.1985373844818679
# 	optimizer: rmsprop
# 2021-07-21 04:29:24,940 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.17470454065187083 --dropout_rate=0.1544424843904443 --layer1_activation=relu --layer1_size=251 --layer_activation=relu --layer_size=53 --learning_rate=0.1985373844818679 --optimizer=rmsprop
# 2021-07-21 04:29:29,955 - wandb.wandb_agent - INFO - Running runs: ['2ovyzaa0']
# 2021-07-21 04:29:29,955 - wandb.wandb_agent - INFO - Cleaning up finished run: 2ovyzaa0
# 2021-07-21 04:29:30,198 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:29:30,198 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.10009882071747907
# 	dropout_rate: 0.135386431881015
# 	layer1_activation: relu
# 	layer1_size: 66
# 	layer_activation: relu
# 	layer_size: 46
# 	learning_rate: 0.05799116379596356
# 	optimizer: rmsprop
# 2021-07-21 04:29:30,200 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.10009882071747907 --dropout_rate=0.135386431881015 --layer1_activation=relu --layer1_size=66 --layer_activation=relu --layer_size=46 --learning_rate=0.05799116379596356 --optimizer=rmsprop
# 2021-07-21 04:29:35,214 - wandb.wandb_agent - INFO - Running runs: ['1skiyd2q']
# 2021-07-21 04:29:35,215 - wandb.wandb_agent - INFO - Cleaning up finished run: 1skiyd2q
# 2021-07-21 04:29:35,481 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:29:35,481 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.17348247494019903
# 	dropout_rate: 0.34848054389778516
# 	layer1_activation: relu
# 	layer1_size: 222
# 	layer_activation: relu
# 	layer_size: 36
# 	learning_rate: 0.15964740680102094
# 	optimizer: rmsprop
# 2021-07-21 04:29:35,483 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.17348247494019903 --dropout_rate=0.34848054389778516 --layer1_activation=relu --layer1_size=222 --layer_activation=relu --layer_size=36 --learning_rate=0.15964740680102094 --optimizer=rmsprop
# 2021-07-21 04:29:40,496 - wandb.wandb_agent - INFO - Running runs: ['s8qvjfpt']
# 2021-07-21 04:29:40,497 - wandb.wandb_agent - INFO - Cleaning up finished run: s8qvjfpt
# 2021-07-21 04:29:40,786 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:29:40,786 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.1354833925072665
# 	dropout_rate: 0.31932931749071597
# 	layer1_activation: relu
# 	layer1_size: 36
# 	layer_activation: relu
# 	layer_size: 24
# 	learning_rate: 0.07573368832833635
# 	optimizer: adam
# 2021-07-21 04:29:40,788 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.1354833925072665 --dropout_rate=0.31932931749071597 --layer1_activation=relu --layer1_size=36 --layer_activation=relu --layer_size=24 --learning_rate=0.07573368832833635 --optimizer=adam
# 2021-07-21 04:29:45,804 - wandb.wandb_agent - INFO - Running runs: ['8vxeqljh']
# 2021-07-21 04:29:45,804 - wandb.wandb_agent - INFO - Cleaning up finished run: 8vxeqljh
# 2021-07-21 04:29:46,057 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:29:46,057 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.06774463647467782
# 	dropout_rate: 0.2696933496737165
# 	layer1_activation: relu
# 	layer1_size: 210
# 	layer_activation: relu
# 	layer_size: 41
# 	learning_rate: 0.05602404351233818
# 	optimizer: rmsprop
# 2021-07-21 04:29:46,060 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.06774463647467782 --dropout_rate=0.2696933496737165 --layer1_activation=relu --layer1_size=210 --layer_activation=relu --layer_size=41 --learning_rate=0.05602404351233818 --optimizer=rmsprop
# 2021-07-21 04:29:51,071 - wandb.wandb_agent - INFO - Running runs: ['fbc2ojdc']
# 2021-07-21 04:29:51,072 - wandb.wandb_agent - INFO - Cleaning up finished run: fbc2ojdc
# 2021-07-21 04:29:51,361 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:29:51,361 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.05255879995501294
# 	dropout_rate: 0.20589344927403086
# 	layer1_activation: relu
# 	layer1_size: 183
# 	layer_activation: relu
# 	layer_size: 55
# 	learning_rate: 0.14418852253923564
# 	optimizer: adam
# 2021-07-21 04:29:51,363 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.05255879995501294 --dropout_rate=0.20589344927403086 --layer1_activation=relu --layer1_size=183 --layer_activation=relu --layer_size=55 --learning_rate=0.14418852253923564 --optimizer=adam
# 2021-07-21 04:29:56,375 - wandb.wandb_agent - INFO - Running runs: ['wn46b6qp']
# 2021-07-21 04:29:56,376 - wandb.wandb_agent - INFO - Cleaning up finished run: wn46b6qp
# 2021-07-21 04:29:56,626 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:29:56,626 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.13479742071443113
# 	dropout_rate: 0.26504268914299656
# 	layer1_activation: relu
# 	layer1_size: 169
# 	layer_activation: relu
# 	layer_size: 45
# 	learning_rate: 0.0552627679767327
# 	optimizer: adam
# 2021-07-21 04:29:56,628 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.13479742071443113 --dropout_rate=0.26504268914299656 --layer1_activation=relu --layer1_size=169 --layer_activation=relu --layer_size=45 --learning_rate=0.0552627679767327 --optimizer=adam
# 2021-07-21 04:30:01,640 - wandb.wandb_agent - INFO - Running runs: ['0u3ov9ly']
# 2021-07-21 04:30:01,640 - wandb.wandb_agent - INFO - Cleaning up finished run: 0u3ov9ly
# 2021-07-21 04:30:01,919 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:30:01,919 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.06047787290237779
# 	dropout_rate: 0.28147803723871073
# 	layer1_activation: relu
# 	layer1_size: 57
# 	layer_activation: relu
# 	layer_size: 24
# 	learning_rate: 0.16372114036088328
# 	optimizer: rmsprop
# 2021-07-21 04:30:01,921 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.06047787290237779 --dropout_rate=0.28147803723871073 --layer1_activation=relu --layer1_size=57 --layer_activation=relu --layer_size=24 --learning_rate=0.16372114036088328 --optimizer=rmsprop
# 2021-07-21 04:30:06,933 - wandb.wandb_agent - INFO - Running runs: ['01vd8n0t']
# 2021-07-21 04:30:06,934 - wandb.wandb_agent - INFO - Cleaning up finished run: 01vd8n0t
# 2021-07-21 04:30:07,322 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:30:07,322 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.16273992292056694
# 	dropout_rate: 0.340835490993451
# 	layer1_activation: relu
# 	layer1_size: 83
# 	layer_activation: relu
# 	layer_size: 49
# 	learning_rate: 0.18519361816976737
# 	optimizer: adam
# 2021-07-21 04:30:07,324 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.16273992292056694 --dropout_rate=0.340835490993451 --layer1_activation=relu --layer1_size=83 --layer_activation=relu --layer_size=49 --learning_rate=0.18519361816976737 --optimizer=adam
# 2021-07-21 04:30:12,335 - wandb.wandb_agent - INFO - Running runs: ['guonjahw']
# 2021-07-21 04:30:12,336 - wandb.wandb_agent - INFO - Cleaning up finished run: guonjahw
# 2021-07-21 04:30:12,599 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:30:12,599 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.19820708955379696
# 	dropout_rate: 0.28071362536567446
# 	layer1_activation: relu
# 	layer1_size: 52
# 	layer_activation: relu
# 	layer_size: 51
# 	learning_rate: 0.18370838692531347
# 	optimizer: rmsprop
# 2021-07-21 04:30:12,601 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.19820708955379696 --dropout_rate=0.28071362536567446 --layer1_activation=relu --layer1_size=52 --layer_activation=relu --layer_size=51 --learning_rate=0.18370838692531347 --optimizer=rmsprop
# 2021-07-21 04:30:17,616 - wandb.wandb_agent - INFO - Running runs: ['vdxhtv1m']
# 2021-07-21 04:30:17,616 - wandb.wandb_agent - INFO - Cleaning up finished run: vdxhtv1m
# 2021-07-21 04:30:17,892 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:30:17,892 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.15940127228059559
# 	dropout_rate: 0.14984821429713693
# 	layer1_activation: relu
# 	layer1_size: 239
# 	layer_activation: relu
# 	layer_size: 64
# 	learning_rate: 0.008115337876174201
# 	optimizer: adam
# 2021-07-21 04:30:17,894 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.15940127228059559 --dropout_rate=0.14984821429713693 --layer1_activation=relu --layer1_size=239 --layer_activation=relu --layer_size=64 --learning_rate=0.008115337876174201 --optimizer=adam
# 2021-07-21 04:30:22,911 - wandb.wandb_agent - INFO - Running runs: ['t34bmbro']
# 2021-07-21 04:30:22,911 - wandb.wandb_agent - INFO - Cleaning up finished run: t34bmbro
# 2021-07-21 04:30:23,280 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:30:23,280 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.12825936546343378
# 	dropout_rate: 0.110366823502701
# 	layer1_activation: relu
# 	layer1_size: 63
# 	layer_activation: relu
# 	layer_size: 34
# 	learning_rate: 0.02680397244569694
# 	optimizer: rmsprop
# 2021-07-21 04:30:23,282 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.12825936546343378 --dropout_rate=0.110366823502701 --layer1_activation=relu --layer1_size=63 --layer_activation=relu --layer_size=34 --learning_rate=0.02680397244569694 --optimizer=rmsprop
# 2021-07-21 04:30:28,294 - wandb.wandb_agent - INFO - Running runs: ['jc9ko7gn']
# 2021-07-21 04:30:28,295 - wandb.wandb_agent - INFO - Cleaning up finished run: jc9ko7gn
# 2021-07-21 04:30:28,529 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:30:28,529 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.07510586891068326
# 	dropout_rate: 0.27716392736957407
# 	layer1_activation: relu
# 	layer1_size: 83
# 	layer_activation: relu
# 	layer_size: 19
# 	learning_rate: 0.18245961525647017
# 	optimizer: rmsprop
# 2021-07-21 04:30:28,531 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.07510586891068326 --dropout_rate=0.27716392736957407 --layer1_activation=relu --layer1_size=83 --layer_activation=relu --layer_size=19 --learning_rate=0.18245961525647017 --optimizer=rmsprop
# 2021-07-21 04:30:33,543 - wandb.wandb_agent - INFO - Running runs: ['sljc7t39']
# 2021-07-21 04:30:33,543 - wandb.wandb_agent - INFO - Cleaning up finished run: sljc7t39
# 2021-07-21 04:30:34,226 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:30:34,226 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.16912063587528264
# 	dropout_rate: 0.3040289626305818
# 	layer1_activation: relu
# 	layer1_size: 20
# 	layer_activation: relu
# 	layer_size: 26
# 	learning_rate: 0.08222313835046138
# 	optimizer: rmsprop
# 2021-07-21 04:30:34,228 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.16912063587528264 --dropout_rate=0.3040289626305818 --layer1_activation=relu --layer1_size=20 --layer_activation=relu --layer_size=26 --learning_rate=0.08222313835046138 --optimizer=rmsprop
# 2021-07-21 04:30:39,240 - wandb.wandb_agent - INFO - Running runs: ['ynyx4bal']
# 2021-07-21 04:30:39,240 - wandb.wandb_agent - INFO - Cleaning up finished run: ynyx4bal
# 2021-07-21 04:30:39,818 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:30:39,818 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.10808877609391575
# 	dropout_rate: 0.12842674181115993
# 	layer1_activation: relu
# 	layer1_size: 105
# 	layer_activation: relu
# 	layer_size: 40
# 	learning_rate: 0.06723141047806307
# 	optimizer: rmsprop
# 2021-07-21 04:30:39,820 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.10808877609391575 --dropout_rate=0.12842674181115993 --layer1_activation=relu --layer1_size=105 --layer_activation=relu --layer_size=40 --learning_rate=0.06723141047806307 --optimizer=rmsprop
# 2021-07-21 04:30:44,832 - wandb.wandb_agent - INFO - Running runs: ['dm0l73yg']
# 2021-07-21 04:30:44,833 - wandb.wandb_agent - INFO - Cleaning up finished run: dm0l73yg
# 2021-07-21 04:30:45,096 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:30:45,096 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.140693164297075
# 	dropout_rate: 0.3587634863845601
# 	layer1_activation: relu
# 	layer1_size: 18
# 	layer_activation: relu
# 	layer_size: 58
# 	learning_rate: 0.03564558565266524
# 	optimizer: rmsprop
# 2021-07-21 04:30:45,098 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.140693164297075 --dropout_rate=0.3587634863845601 --layer1_activation=relu --layer1_size=18 --layer_activation=relu --layer_size=58 --learning_rate=0.03564558565266524 --optimizer=rmsprop
# 2021-07-21 04:30:50,117 - wandb.wandb_agent - INFO - Running runs: ['w9mkt2mx']
# 2021-07-21 04:30:50,117 - wandb.wandb_agent - INFO - Cleaning up finished run: w9mkt2mx
# 2021-07-21 04:30:50,398 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:30:50,398 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.07727677456440543
# 	dropout_rate: 0.3698397188642899
# 	layer1_activation: relu
# 	layer1_size: 154
# 	layer_activation: relu
# 	layer_size: 32
# 	learning_rate: 0.03673602085653349
# 	optimizer: adam
# 2021-07-21 04:30:50,400 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.07727677456440543 --dropout_rate=0.3698397188642899 --layer1_activation=relu --layer1_size=154 --layer_activation=relu --layer_size=32 --learning_rate=0.03673602085653349 --optimizer=adam
# 2021-07-21 04:30:55,413 - wandb.wandb_agent - INFO - Running runs: ['jhxmpspn']
# 2021-07-21 04:30:55,414 - wandb.wandb_agent - INFO - Cleaning up finished run: jhxmpspn
# 2021-07-21 04:30:55,674 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:30:55,674 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.19694650880503767
# 	dropout_rate: 0.24458588865416642
# 	layer1_activation: relu
# 	layer1_size: 164
# 	layer_activation: relu
# 	layer_size: 21
# 	learning_rate: 0.027220392554308026
# 	optimizer: rmsprop
# 2021-07-21 04:30:55,676 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.19694650880503767 --dropout_rate=0.24458588865416642 --layer1_activation=relu --layer1_size=164 --layer_activation=relu --layer_size=21 --learning_rate=0.027220392554308026 --optimizer=rmsprop
# 2021-07-21 04:31:00,684 - wandb.wandb_agent - INFO - Running runs: ['wb7o5idv']
# 2021-07-21 04:31:00,684 - wandb.wandb_agent - INFO - Cleaning up finished run: wb7o5idv
# 2021-07-21 04:31:01,014 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:31:01,014 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.09991649695417756
# 	dropout_rate: 0.2885725400465672
# 	layer1_activation: relu
# 	layer1_size: 57
# 	layer_activation: relu
# 	layer_size: 38
# 	learning_rate: 0.09597716933990372
# 	optimizer: rmsprop
# 2021-07-21 04:31:01,016 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.09991649695417756 --dropout_rate=0.2885725400465672 --layer1_activation=relu --layer1_size=57 --layer_activation=relu --layer_size=38 --learning_rate=0.09597716933990372 --optimizer=rmsprop
# 2021-07-21 04:31:06,025 - wandb.wandb_agent - INFO - Running runs: ['uu1r39ct']
# 2021-07-21 04:31:06,026 - wandb.wandb_agent - INFO - Cleaning up finished run: uu1r39ct
# 2021-07-21 04:31:06,295 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:31:06,295 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.11573286519513461
# 	dropout_rate: 0.1673286232214083
# 	layer1_activation: relu
# 	layer1_size: 230
# 	layer_activation: relu
# 	layer_size: 30
# 	learning_rate: 0.09196685230770892
# 	optimizer: adam
# 2021-07-21 04:31:06,297 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.11573286519513461 --dropout_rate=0.1673286232214083 --layer1_activation=relu --layer1_size=230 --layer_activation=relu --layer_size=30 --learning_rate=0.09196685230770892 --optimizer=adam
# 2021-07-21 04:31:11,309 - wandb.wandb_agent - INFO - Running runs: ['wsg772gt']
# 2021-07-21 04:31:11,310 - wandb.wandb_agent - INFO - Cleaning up finished run: wsg772gt
# 2021-07-21 04:31:11,604 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:31:11,604 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.14550161094531722
# 	dropout_rate: 0.15093837753534206
# 	layer1_activation: relu
# 	layer1_size: 73
# 	layer_activation: relu
# 	layer_size: 26
# 	learning_rate: 0.1664293280131089
# 	optimizer: rmsprop
# 2021-07-21 04:31:11,607 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.14550161094531722 --dropout_rate=0.15093837753534206 --layer1_activation=relu --layer1_size=73 --layer_activation=relu --layer_size=26 --learning_rate=0.1664293280131089 --optimizer=rmsprop
# 2021-07-21 04:31:16,622 - wandb.wandb_agent - INFO - Running runs: ['3i8597uo']
# 2021-07-21 04:31:16,622 - wandb.wandb_agent - INFO - Cleaning up finished run: 3i8597uo
# 2021-07-21 04:31:17,536 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:31:17,536 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.18879888236331205
# 	dropout_rate: 0.3567054304739756
# 	layer1_activation: relu
# 	layer1_size: 54
# 	layer_activation: relu
# 	layer_size: 29
# 	learning_rate: 0.11225345759177784
# 	optimizer: adam
# 2021-07-21 04:31:17,538 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.18879888236331205 --dropout_rate=0.3567054304739756 --layer1_activation=relu --layer1_size=54 --layer_activation=relu --layer_size=29 --learning_rate=0.11225345759177784 --optimizer=adam
# 2021-07-21 04:31:22,550 - wandb.wandb_agent - INFO - Running runs: ['nbmlyjsc']
# 2021-07-21 04:31:22,550 - wandb.wandb_agent - INFO - Cleaning up finished run: nbmlyjsc
# 2021-07-21 04:31:22,856 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:31:22,857 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.06825721121350074
# 	dropout_rate: 0.31998021529507326
# 	layer1_activation: relu
# 	layer1_size: 78
# 	layer_activation: relu
# 	layer_size: 62
# 	learning_rate: 0.12876362771025116
# 	optimizer: rmsprop
# 2021-07-21 04:31:22,859 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.06825721121350074 --dropout_rate=0.31998021529507326 --layer1_activation=relu --layer1_size=78 --layer_activation=relu --layer_size=62 --learning_rate=0.12876362771025116 --optimizer=rmsprop
# 2021-07-21 04:31:27,871 - wandb.wandb_agent - INFO - Running runs: ['s9e00njc']
# 2021-07-21 04:31:27,872 - wandb.wandb_agent - INFO - Cleaning up finished run: s9e00njc
# 2021-07-21 04:31:28,171 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:31:28,171 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.1752389847423026
# 	dropout_rate: 0.16770501968360543
# 	layer1_activation: relu
# 	layer1_size: 33
# 	layer_activation: relu
# 	layer_size: 47
# 	learning_rate: 0.18052197757408112
# 	optimizer: adam
# ...
# 2021-07-21 04:59:08,976 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.15055356820532526
# 	dropout_rate: 0.18325302884910363
# 	layer1_activation: relu
# 	layer1_size: 131
# 	layer_activation: relu
# 	layer_size: 30
# 	learning_rate: 0.07662868244153609
# 	optimizer: rmsprop
# 2021-07-21 04:59:08,979 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.15055356820532526 --dropout_rate=0.18325302884910363 --layer1_activation=relu --layer1_size=131 --layer_activation=relu --layer_size=30 --learning_rate=0.07662868244153609 --optimizer=rmsprop
# 2021-07-21 04:59:13,991 - wandb.wandb_agent - INFO - Running runs: ['lzt08dmx']
# 2021-07-21 04:59:13,991 - wandb.wandb_agent - INFO - Cleaning up finished run: lzt08dmx
# 2021-07-21 04:59:14,245 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:59:14,245 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.06595716238951055
# 	dropout_rate: 0.32229778162657063
# 	layer1_activation: relu
# 	layer1_size: 177
# 	layer_activation: relu
# 	layer_size: 17
# 	learning_rate: 0.11894782828637802
# 	optimizer: adam
# 2021-07-21 04:59:14,248 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.06595716238951055 --dropout_rate=0.32229778162657063 --layer1_activation=relu --layer1_size=177 --layer_activation=relu --layer_size=17 --learning_rate=0.11894782828637802 --optimizer=adam
# 2021-07-21 04:59:19,262 - wandb.wandb_agent - INFO - Running runs: ['6bgnicg0']
# 2021-07-21 04:59:19,262 - wandb.wandb_agent - INFO - Cleaning up finished run: 6bgnicg0
# 2021-07-21 04:59:19,554 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:59:19,555 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.13544992287539048
# 	dropout_rate: 0.3713263381157069
# 	layer1_activation: relu
# 	layer1_size: 52
# 	layer_activation: relu
# 	layer_size: 29
# 	learning_rate: 0.16860582092459436
# 	optimizer: adam
# 2021-07-21 04:59:19,557 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.13544992287539048 --dropout_rate=0.3713263381157069 --layer1_activation=relu --layer1_size=52 --layer_activation=relu --layer_size=29 --learning_rate=0.16860582092459436 --optimizer=adam
# 2021-07-21 04:59:24,569 - wandb.wandb_agent - INFO - Running runs: ['3c7zvzws']
# 2021-07-21 04:59:24,570 - wandb.wandb_agent - INFO - Cleaning up finished run: 3c7zvzws
# 2021-07-21 04:59:24,871 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:59:24,871 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.18359806647428734
# 	dropout_rate: 0.3287589236512938
# 	layer1_activation: relu
# 	layer1_size: 62
# 	layer_activation: relu
# 	layer_size: 63
# 	learning_rate: 0.18895813912588347
# 	optimizer: rmsprop
# 2021-07-21 04:59:24,873 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.18359806647428734 --dropout_rate=0.3287589236512938 --layer1_activation=relu --layer1_size=62 --layer_activation=relu --layer_size=63 --learning_rate=0.18895813912588347 --optimizer=rmsprop
# 2021-07-21 04:59:29,884 - wandb.wandb_agent - INFO - Running runs: ['xltq27dp']
# 2021-07-21 04:59:29,885 - wandb.wandb_agent - INFO - Cleaning up finished run: xltq27dp
# 2021-07-21 04:59:30,169 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:59:30,169 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.08838508247603406
# 	dropout_rate: 0.11025837038506564
# 	layer1_activation: relu
# 	layer1_size: 101
# 	layer_activation: relu
# 	layer_size: 43
# 	learning_rate: 0.18355265894516545
# 	optimizer: rmsprop
# 2021-07-21 04:59:30,174 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.08838508247603406 --dropout_rate=0.11025837038506564 --layer1_activation=relu --layer1_size=101 --layer_activation=relu --layer_size=43 --learning_rate=0.18355265894516545 --optimizer=rmsprop
# 2021-07-21 04:59:35,184 - wandb.wandb_agent - INFO - Running runs: ['kx700fu7']
# 2021-07-21 04:59:35,184 - wandb.wandb_agent - INFO - Cleaning up finished run: kx700fu7
# 2021-07-21 04:59:35,512 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:59:35,513 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.11639476781219439
# 	dropout_rate: 0.19789939337065027
# 	layer1_activation: relu
# 	layer1_size: 39
# 	layer_activation: relu
# 	layer_size: 16
# 	learning_rate: 0.08261494142288801
# 	optimizer: adam
# 2021-07-21 04:59:35,515 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.11639476781219439 --dropout_rate=0.19789939337065027 --layer1_activation=relu --layer1_size=39 --layer_activation=relu --layer_size=16 --learning_rate=0.08261494142288801 --optimizer=adam
# 2021-07-21 04:59:40,527 - wandb.wandb_agent - INFO - Running runs: ['awlouxgt']
# 2021-07-21 04:59:40,528 - wandb.wandb_agent - INFO - Cleaning up finished run: awlouxgt
# 2021-07-21 04:59:40,878 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:59:40,878 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.11970886575699001
# 	dropout_rate: 0.17240492334025187
# 	layer1_activation: relu
# 	layer1_size: 203
# 	layer_activation: relu
# 	layer_size: 52
# 	learning_rate: 0.027209770559611005
# 	optimizer: adam
# 2021-07-21 04:59:40,880 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.11970886575699001 --dropout_rate=0.17240492334025187 --layer1_activation=relu --layer1_size=203 --layer_activation=relu --layer_size=52 --learning_rate=0.027209770559611005 --optimizer=adam
# 2021-07-21 04:59:45,892 - wandb.wandb_agent - INFO - Running runs: ['3xcmgfww']
# 2021-07-21 04:59:45,893 - wandb.wandb_agent - INFO - Cleaning up finished run: 3xcmgfww
# 2021-07-21 04:59:46,158 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:59:46,158 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.12014545494814959
# 	dropout_rate: 0.22530738085318572
# 	layer1_activation: relu
# 	layer1_size: 168
# 	layer_activation: relu
# 	layer_size: 50
# 	learning_rate: 0.06502516657879456
# 	optimizer: rmsprop
# 2021-07-21 04:59:46,160 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.12014545494814959 --dropout_rate=0.22530738085318572 --layer1_activation=relu --layer1_size=168 --layer_activation=relu --layer_size=50 --learning_rate=0.06502516657879456 --optimizer=rmsprop
# 2021-07-21 04:59:51,172 - wandb.wandb_agent - INFO - Running runs: ['g5br7ofq']
# 2021-07-21 04:59:51,172 - wandb.wandb_agent - INFO - Cleaning up finished run: g5br7ofq
# 2021-07-21 04:59:51,537 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:59:51,538 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.05096409645066543
# 	dropout_rate: 0.2880874019776203
# 	layer1_activation: relu
# 	layer1_size: 70
# 	layer_activation: relu
# 	layer_size: 36
# 	learning_rate: 0.007752974721371428
# 	optimizer: adam
# 2021-07-21 04:59:51,540 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.05096409645066543 --dropout_rate=0.2880874019776203 --layer1_activation=relu --layer1_size=70 --layer_activation=relu --layer_size=36 --learning_rate=0.007752974721371428 --optimizer=adam
# 2021-07-21 04:59:56,552 - wandb.wandb_agent - INFO - Running runs: ['jzgdpqx6']
# 2021-07-21 04:59:56,552 - wandb.wandb_agent - INFO - Cleaning up finished run: jzgdpqx6
# 2021-07-21 04:59:56,853 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 04:59:56,854 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.1102672110954435
# 	dropout_rate: 0.24949289095136318
# 	layer1_activation: relu
# 	layer1_size: 41
# 	layer_activation: relu
# 	layer_size: 56
# 	learning_rate: 0.14283803073513288
# 	optimizer: rmsprop
# 2021-07-21 04:59:56,856 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.1102672110954435 --dropout_rate=0.24949289095136318 --layer1_activation=relu --layer1_size=41 --layer_activation=relu --layer_size=56 --learning_rate=0.14283803073513288 --optimizer=rmsprop
# 2021-07-21 05:00:01,868 - wandb.wandb_agent - INFO - Running runs: ['oaaq31kn']
# 2021-07-21 05:00:01,869 - wandb.wandb_agent - INFO - Cleaning up finished run: oaaq31kn
# 2021-07-21 05:00:02,165 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 05:00:02,165 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.08521331613133552
# 	dropout_rate: 0.35167856784637497
# 	layer1_activation: relu
# 	layer1_size: 79
# 	layer_activation: relu
# 	layer_size: 21
# 	learning_rate: 0.16632373963508182
# 	optimizer: adam
# 2021-07-21 05:00:02,167 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.08521331613133552 --dropout_rate=0.35167856784637497 --layer1_activation=relu --layer1_size=79 --layer_activation=relu --layer_size=21 --learning_rate=0.16632373963508182 --optimizer=adam
# 2021-07-21 05:00:07,179 - wandb.wandb_agent - INFO - Running runs: ['ttyzsguj']
# 2021-07-21 05:00:07,179 - wandb.wandb_agent - INFO - Cleaning up finished run: ttyzsguj
# 2021-07-21 05:00:07,474 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 05:00:07,474 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.05226976902525319
# 	dropout_rate: 0.1864870572035776
# 	layer1_activation: relu
# 	layer1_size: 64
# 	layer_activation: relu
# 	layer_size: 32
# 	learning_rate: 0.13568012594427722
# 	optimizer: rmsprop
# 2021-07-21 05:00:07,476 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.05226976902525319 --dropout_rate=0.1864870572035776 --layer1_activation=relu --layer1_size=64 --layer_activation=relu --layer_size=32 --learning_rate=0.13568012594427722 --optimizer=rmsprop
# 2021-07-21 05:00:12,488 - wandb.wandb_agent - INFO - Running runs: ['stw953fc']
# 2021-07-21 05:00:12,489 - wandb.wandb_agent - INFO - Cleaning up finished run: stw953fc
# 2021-07-21 05:00:12,826 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 05:00:12,827 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.1777884251921057
# 	dropout_rate: 0.3841737666260996
# 	layer1_activation: relu
# 	layer1_size: 72
# 	layer_activation: relu
# 	layer_size: 36
# 	learning_rate: 0.11375191696946611
# 	optimizer: adam
# 2021-07-21 05:00:12,829 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.1777884251921057 --dropout_rate=0.3841737666260996 --layer1_activation=relu --layer1_size=72 --layer_activation=relu --layer_size=36 --learning_rate=0.11375191696946611 --optimizer=adam
# 2021-07-21 05:00:17,842 - wandb.wandb_agent - INFO - Running runs: ['i60ymk4f']
# 2021-07-21 05:00:17,843 - wandb.wandb_agent - INFO - Cleaning up finished run: i60ymk4f
# 2021-07-21 05:00:18,231 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 05:00:18,231 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.13515590059534638
# 	dropout_rate: 0.11067915552073532
# 	layer1_activation: relu
# 	layer1_size: 136
# 	layer_activation: relu
# 	layer_size: 21
# 	learning_rate: 0.14529021760367508
# 	optimizer: rmsprop
# 2021-07-21 05:00:18,233 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.13515590059534638 --dropout_rate=0.11067915552073532 --layer1_activation=relu --layer1_size=136 --layer_activation=relu --layer_size=21 --learning_rate=0.14529021760367508 --optimizer=rmsprop
# 2021-07-21 05:00:23,244 - wandb.wandb_agent - INFO - Running runs: ['abi2u0d3']
# 2021-07-21 05:00:23,244 - wandb.wandb_agent - INFO - Cleaning up finished run: abi2u0d3
# 2021-07-21 05:00:23,658 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 05:00:23,659 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.0893941894627481
# 	dropout_rate: 0.2194700580782345
# 	layer1_activation: relu
# 	layer1_size: 117
# 	layer_activation: relu
# 	layer_size: 18
# 	learning_rate: 0.10044862898150099
# 	optimizer: adam
# 2021-07-21 05:00:23,661 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.0893941894627481 --dropout_rate=0.2194700580782345 --layer1_activation=relu --layer1_size=117 --layer_activation=relu --layer_size=18 --learning_rate=0.10044862898150099 --optimizer=adam
# 2021-07-21 05:00:28,672 - wandb.wandb_agent - INFO - Running runs: ['fb7w7akh']
# 2021-07-21 05:00:28,673 - wandb.wandb_agent - INFO - Cleaning up finished run: fb7w7akh
# 2021-07-21 05:00:29,226 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 05:00:29,226 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.07319120451110629
# 	dropout_rate: 0.2938516169955053
# 	layer1_activation: relu
# 	layer1_size: 68
# 	layer_activation: relu
# 	layer_size: 54
# 	learning_rate: 0.032463655441508664
# 	optimizer: adam
# 2021-07-21 05:00:29,228 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.07319120451110629 --dropout_rate=0.2938516169955053 --layer1_activation=relu --layer1_size=68 --layer_activation=relu --layer_size=54 --learning_rate=0.032463655441508664 --optimizer=adam
# 2021-07-21 05:00:34,240 - wandb.wandb_agent - INFO - Running runs: ['rq61p1hy']
# 2021-07-21 05:00:34,241 - wandb.wandb_agent - INFO - Cleaning up finished run: rq61p1hy
# 2021-07-21 05:00:34,479 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 05:00:34,479 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.10859558081803602
# 	dropout_rate: 0.39462555248658737
# 	layer1_activation: relu
# 	layer1_size: 174
# 	layer_activation: relu
# 	layer_size: 45
# 	learning_rate: 0.006686990541613915
# 	optimizer: adam
# 2021-07-21 05:00:34,482 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.10859558081803602 --dropout_rate=0.39462555248658737 --layer1_activation=relu --layer1_size=174 --layer_activation=relu --layer_size=45 --learning_rate=0.006686990541613915 --optimizer=adam
# 2021-07-21 05:00:39,495 - wandb.wandb_agent - INFO - Running runs: ['8jl826xm']
# 2021-07-21 05:00:39,496 - wandb.wandb_agent - INFO - Cleaning up finished run: 8jl826xm
# 2021-07-21 05:00:39,806 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 05:00:39,806 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.16795089257304646
# 	dropout_rate: 0.3011434769853586
# 	layer1_activation: relu
# 	layer1_size: 223
# 	layer_activation: relu
# 	layer_size: 37
# 	learning_rate: 0.06346430826448246
# 	optimizer: rmsprop
# 2021-07-21 05:00:39,808 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.16795089257304646 --dropout_rate=0.3011434769853586 --layer1_activation=relu --layer1_size=223 --layer_activation=relu --layer_size=37 --learning_rate=0.06346430826448246 --optimizer=rmsprop
# 2021-07-21 05:00:44,822 - wandb.wandb_agent - INFO - Running runs: ['h3n3goy3']
# 2021-07-21 05:00:44,822 - wandb.wandb_agent - INFO - Cleaning up finished run: h3n3goy3
# 2021-07-21 05:00:45,177 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-07-21 05:00:45,177 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropoout_rate: 0.06419741539302991
# 	dropout_rate: 0.20131885225048224
# 	layer1_activation: relu
# 	layer1_size: 225
# 	layer_activation: relu
# 	layer_size: 52
# 	learning_rate: 0.08815459778942376
# 	optimizer: adam
# 2021-07-21 05:00:45,179 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropoout_rate=0.06419741539302991 --dropout_rate=0.20131885225048224 --layer1_activation=relu --layer1_size=225 --layer_activation=relu --layer_size=52 --learning_rate=0.08815459778942376 --optimizer=adam
